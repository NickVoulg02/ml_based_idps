# %%
import kagglehub
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from dython.nominal import associations

import matplotlib.pyplot as plt
import seaborn as sns


#download dataset from kagglehub
path = kagglehub.dataset_download("ekkykharismadhany/csecicids2018-cleaned")
print("Files stored successfully!!")
# Out:
# Files stored successfully!!

# %%
#load csv to dataframe
df1 = pd.read_csv(path+"/cleaned_ids2018_sampled.csv")

#drop "Label" and "Unnamed" cols and store the df in X
X = df1.drop(columns=['Label', 'Unnamed: 0'])

#classes: 0 for normal traffic and 1 for attack
Y_bin = df1['Label'].apply(lambda x: 0 if x == 1 else 1)

#make the classes to be from 0 to n-1
Y_multi = df1['Label'] - df1['Label'].min()

# %%
eda_df = X.copy()
eda_df['target'] = Y_bin.reset_index(drop=True)

# Get correlation of all features with target
correlations = eda_df.corr(numeric_only=True)['target'].abs().sort_values(ascending=False)

top_features = correlations.drop('target').head(16).index.tolist()

# %%
# Full heatmap
associations(
    eda_df,
    nominal_columns='auto',
    figsize=(50, 50),
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    title="Feature Associations",
    cbar=False  # adds or removes color bar
)
# Out:
# {'corr':                Dst Port  Protocol  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
#  Dst Port       1.000000 -0.242222      -0.001371     -0.002823     -0.015514
#  Protocol      -0.242222  1.000000      -0.007102     -0.013483     -0.016525
#  Flow Duration -0.001371 -0.007102       1.000000      0.000408      0.002635
#  Tot Fwd Pkts  -0.002823 -0.013483       0.000408      1.000000      0.139380
#  Tot Bwd Pkts  -0.015514 -0.016525       0.002635      0.139380      1.000000
#  ...                 ...       ...            ...           ...           ...
#  Idle Mean      0.009345 -0.018476      -0.217612      0.000805      0.002809
#  Idle Std      -0.000792 -0.001890      -0.221639      0.000121      0.000415
#  Idle Max       0.005406 -0.011979      -0.219448      0.000536      0.001857
#  Idle Min       0.067265 -0.113453      -0.143864      0.004879      0.017343
#  target        -0.216085 -0.268338      -0.007199     -0.009240     -0.013206
#
#                 TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
#  Dst Port             -0.007538        -0.009172         0.237565
#  Protocol              0.026454        -0.009626        -0.269706
#  Flow Duration         0.002312         0.001774         0.003400
#  Tot Fwd Pkts         -0.143194         0.159925         0.018375
#  Tot Bwd Pkts          0.007759         0.742054         0.038570
#  ...                        ...              ...              ...
#  Idle Mean            -0.000441         0.002124        -0.007742
#  Idle Std             -0.000014         0.000316        -0.000175
#  Idle Max             -0.000273         0.001406        -0.004821
#  Idle Min             -0.002873         0.013129        -0.050948
#  target                0.027252        -0.009984        -0.159792
#
#                 Fwd Pkt Len Min  Fwd Pkt Len Mean  ...  Fwd Seg Size Min  \
#  Dst Port             -0.186307          0.184207  ...          0.114142
#  Protocol              0.748082         -0.061303  ...         -0.695262
#  Flow Duration        -0.004176         -0.001176  ...          0.002626
#  Tot Fwd Pkts         -0.008983          0.007804  ...          0.008962
#  Tot Bwd Pkts         -0.013616          0.007574  ...          0.011023
#  ...                        ...               ...  ...               ...
#  Idle Mean            -0.008866         -0.012778  ...         -0.002884
#  Idle Std              0.000514          0.000104  ...         -0.002114
#  Idle Max             -0.004988         -0.007642  ...         -0.002575
#  Idle Min             -0.061243         -0.085175  ...         -0.006641
#  target               -0.216284         -0.177857  ...          0.481460
#
#                 Active Mean  Active Std  Active Max  Active Min  Idle Mean  \
#  Dst Port         -0.024373   -0.027509   -0.034613   -0.017458   0.009345
#  Protocol         -0.037773   -0.035613   -0.046486   -0.029672  -0.018476
#  Flow Duration     0.005768    0.006864    0.008487    0.004001  -0.217612
#  Tot Fwd Pkts      0.018419    0.010928    0.020235    0.016599   0.000805
#  Tot Bwd Pkts      0.090977    0.041523    0.093406    0.086834   0.002809
#  ...                    ...         ...         ...         ...        ...
#  Idle Mean         0.006440    0.005407    0.006907    0.005071   1.000000
#  Idle Std          0.002271    0.001911    0.002359    0.001744   0.994975
#  Idle Max          0.005040    0.004127    0.005335    0.003990   0.999230
#  Idle Min          0.034644    0.029002    0.037066    0.027405   0.802149
#  target           -0.023981   -0.023961   -0.034335   -0.018786  -0.014307
#
#                 Idle Std  Idle Max  Idle Min    target
#  Dst Port      -0.000792  0.005406  0.067265 -0.216085
#  Protocol      -0.001890 -0.011979 -0.113453 -0.268338
#  Flow Duration -0.221639 -0.219448 -0.143864 -0.007199
#  Tot Fwd Pkts   0.000121  0.000536  0.004879 -0.009240
#  Tot Bwd Pkts   0.000415  0.001857  0.017343 -0.013206
#  ...                 ...       ...       ...       ...
#  Idle Mean      0.994975  0.999230  0.802149 -0.014307
#  Idle Std       1.000000  0.998134  0.738412 -0.000722
#  Idle Max       0.998134  1.000000  0.778152 -0.008943
#  Idle Min       0.738412  0.778152  1.000000 -0.092209
#  target        -0.000722 -0.008943 -0.092209  1.000000
#
#  [78 rows x 78 columns],
#  'ax': <Axes: title={'center': 'Feature Associations'}>}

# %%
# Subset DataFrame for heatmap
subset_df = eda_df[top_features + ['target']]

associations(
    subset_df,
    nominal_columns='auto',
    figsize=(18, 18),
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    title="Top 16 Features - Feature Associations",
    cbar=False
)
# Out:
# {'corr':                    Fwd Seg Size Min  Init Fwd Win Byts  Bwd Pkts/s  Protocol  \
#  Fwd Seg Size Min           1.000000           0.322275    0.484619 -0.695262
#  Init Fwd Win Byts          0.322275           1.000000    0.061032 -0.350785
#  Bwd Pkts/s                 0.484619           0.061032    1.000000 -0.089422
#  Protocol                  -0.695262          -0.350785   -0.089422  1.000000
#  ACK Flag Cnt               0.228171           0.038825   -0.058614 -0.354147
#  Bwd Pkt Len Min           -0.644815          -0.319192   -0.081961  0.851533
#  Init Bwd Win Byts          0.107274           0.150700   -0.081186 -0.225162
#  Pkt Size Avg              -0.076434           0.070403   -0.138735  0.036043
#  Pkt Len Min               -0.592291          -0.293143   -0.074379  0.782197
#  Flow Pkts/s                0.414774           0.016553    0.802719 -0.103444
#  Fwd Pkt Len Min           -0.566562          -0.283609   -0.059010  0.748082
#  Dst Port                   0.114142           0.375721   -0.065790 -0.242222
#  Pkt Len Mean              -0.011819           0.080616   -0.127575 -0.046539
#  Bwd Seg Size Avg          -0.036310           0.011292   -0.119714 -0.011447
#  Bwd Pkt Len Mean          -0.036310           0.011292   -0.119714 -0.011447
#  Fwd IAT Tot               -0.005518           0.076330   -0.072209 -0.219078
#  target                     0.481460           0.303419    0.302897 -0.268338
#
#                     ACK Flag Cnt  Bwd Pkt Len Min  Init Bwd Win Byts  \
#  Fwd Seg Size Min       0.228171        -0.644815           0.107274
#  Init Fwd Win Byts      0.038825        -0.319192           0.150700
#  Bwd Pkts/s            -0.058614        -0.081961          -0.081186
#  Protocol              -0.354147         0.851533          -0.225162
#  ACK Flag Cnt           1.000000        -0.315985          -0.291983
#  Bwd Pkt Len Min       -0.315985         1.000000          -0.204226
#  Init Bwd Win Byts     -0.291983        -0.204226           1.000000
#  Pkt Size Avg          -0.497562         0.078153           0.286409
#  Pkt Len Min           -0.291161         0.713484          -0.188378
#  Flow Pkts/s            0.027585        -0.094733          -0.093168
#  Fwd Pkt Len Min       -0.273070         0.683894          -0.182602
#  Dst Port               0.253471        -0.224930           0.128027
#  Pkt Len Mean          -0.455791        -0.009329           0.298820
#  Bwd Seg Size Avg      -0.444783         0.055541           0.232273
#  Bwd Pkt Len Mean      -0.444783         0.055541           0.232273
#  Fwd IAT Tot            0.042998        -0.164556          -0.108759
#  target                 0.249186        -0.246304          -0.239694
#
#                     Pkt Size Avg  Pkt Len Min  Flow Pkts/s  Fwd Pkt Len Min  \
#  Fwd Seg Size Min      -0.076434    -0.592291     0.414774        -0.566562
#  Init Fwd Win Byts      0.070403    -0.293143     0.016553        -0.283609
#  Bwd Pkts/s            -0.138735    -0.074379     0.802719        -0.059010
#  Protocol               0.036043     0.782197    -0.103444         0.748082
#  ACK Flag Cnt          -0.497562    -0.291161     0.027585        -0.273070
#  Bwd Pkt Len Min        0.078153     0.713484    -0.094733         0.683894
#  Init Bwd Win Byts      0.286409    -0.188378    -0.093168        -0.182602
#  Pkt Size Avg           1.000000     0.111859    -0.153892         0.126580
#  Pkt Len Min            0.111859     1.000000    -0.086023         0.961488
#  Flow Pkts/s           -0.153892    -0.086023     1.000000        -0.074846
#  Fwd Pkt Len Min        0.126580     0.961488    -0.074846         1.000000
#  Dst Port              -0.059629    -0.198041     0.065000        -0.186307
#  Pkt Len Mean           0.993817     0.026776    -0.142285         0.042993
#  Bwd Seg Size Avg       0.944974    -0.009503    -0.137346        -0.011039
#  Bwd Pkt Len Mean       0.944974    -0.009503    -0.137346        -0.011039
#  Fwd IAT Tot            0.180332    -0.114877    -0.082320        -0.110918
#  target                -0.232379    -0.223835     0.220129        -0.216284
#
#                     Dst Port  Pkt Len Mean  Bwd Seg Size Avg  Bwd Pkt Len Mean  \
#  Fwd Seg Size Min   0.114142     -0.011819         -0.036310         -0.036310
#  Init Fwd Win Byts  0.375721      0.080616          0.011292          0.011292
#  Bwd Pkts/s        -0.065790     -0.127575         -0.119714         -0.119714
#  Protocol          -0.242222     -0.046539         -0.011447         -0.011447
#  ACK Flag Cnt       0.253471     -0.455791         -0.444783         -0.444783
#  Bwd Pkt Len Min   -0.224930     -0.009329          0.055541          0.055541
#  Init Bwd Win Byts  0.128027      0.298820          0.232273          0.232273
#  Pkt Size Avg      -0.059629      0.993817          0.944974          0.944974
#  Pkt Len Min       -0.198041      0.026776         -0.009503         -0.009503
#  Flow Pkts/s        0.065000     -0.142285         -0.137346         -0.137346
#  Fwd Pkt Len Min   -0.186307      0.042993         -0.011039         -0.011039
#  Dst Port           1.000000     -0.053369         -0.136501         -0.136501
#  Pkt Len Mean      -0.053369      1.000000          0.952221          0.952221
#  Bwd Seg Size Avg  -0.136501      0.952221          1.000000          1.000000
#  Bwd Pkt Len Mean  -0.136501      0.952221          1.000000          1.000000
#  Fwd IAT Tot       -0.042579      0.213370          0.226283          0.226283
#  target            -0.216085     -0.208220         -0.207115         -0.207115
#
#                     Fwd IAT Tot    target
#  Fwd Seg Size Min     -0.005518  0.481460
#  Init Fwd Win Byts     0.076330  0.303419
#  Bwd Pkts/s           -0.072209  0.302897
#  Protocol             -0.219078 -0.268338
#  ACK Flag Cnt          0.042998  0.249186
#  Bwd Pkt Len Min      -0.164556 -0.246304
#  Init Bwd Win Byts    -0.108759 -0.239694
#  Pkt Size Avg          0.180332 -0.232379
#  Pkt Len Min          -0.114877 -0.223835
#  Flow Pkts/s          -0.082320  0.220129
#  Fwd Pkt Len Min      -0.110918 -0.216284
#  Dst Port             -0.042579 -0.216085
#  Pkt Len Mean          0.213370 -0.208220
#  Bwd Seg Size Avg      0.226283 -0.207115
#  Bwd Pkt Len Mean      0.226283 -0.207115
#  Fwd IAT Tot           1.000000 -0.188536
#  target               -0.188536  1.000000  ,
#  'ax': <Axes: title={'center': 'Top 16 Features - Feature Associations'}>}

# %%
sns.set_style('whitegrid')

features_per_plot = 4  # 4 plots per figure

for plot_idx in range(4):  # 4 figures
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle(f'Strip Plots of Selected Features by Traffic Type (Part {plot_idx + 1})', fontsize=20)

    for i in range(features_per_plot):
        feature_idx = plot_idx * features_per_plot + i
        if feature_idx >= len(top_features):
            break

        feature = top_features[feature_idx]
        row, col = divmod(i, 2)

        sns.stripplot(
            data=eda_df, x='target', y=feature, hue='target', dodge=False,
            jitter=0.3, alpha=0.6, ax=axes[row, col], palette={0: 'green', 1: 'red'}
        )
        axes[row, col].set_title(f'{feature} vs Target')
        axes[row, col].legend_.remove()
        axes[row, col].set_xlabel("Traffic Type (0 = Normal, 1 = Attack)")

    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, ['Normal', 'Attack'], loc='upper right', fontsize=14)

    plt.tight_layout()
    plt.subplots_adjust(top=0.90)
    plt.show()

# %%
mapped_labels = Y_bin.map({0: 'Normal', 1: 'Attack'})

plt.figure(figsize=(10, 6))
ax = sns.countplot(x=mapped_labels, width=0.6)
plt.title("Binary Class Distribution")

plt.xticks(ha='center', fontsize=12)

for p in ax.patches:
    height = p.get_height()
    ax.text(
        p.get_x() + p.get_width() / 2.,
        height + 0.1,
        int(height),
        ha="center",
        va="bottom",
        fontsize=10
    )

plt.subplots_adjust(bottom=0.2)
plt.show()

# %%
label_dict = {
    0: 'Benign',
    1: 'FTP-BruteForce',
    2: 'SSH-Bruteforce',
    3: 'DDOS attack-HOIC',
    4: 'Bot',
    5: 'DoS attacks-GoldenEye',
    6: 'DoS attacks-Slowloris',
    7: 'DDOS attack-LOIC-UDP',
    8: 'Brute Force -Web',
    9: 'Brute Force -XSS',
    10: 'SQL Injection'
}

plt.figure(figsize=(28, 8))
ax = sns.countplot(x=Y_multi.map(label_dict), width=0.6)
plt.title("Multi-Class Label Distribution")

plt.xticks(ha='center', fontsize=12)

for p in ax.patches:
    height = p.get_height()
    ax.text(
        p.get_x() + p.get_width() / 2.,
        height + 0.1,
        int(height),
        ha="center",
        va="bottom",
        fontsize=10
    )

plt.subplots_adjust(bottom=0.3)
plt.show()

# %%
#calculate the correlation matrix
corr_matrix = X.corr(numeric_only=True)

# set a threshold for high correlation
threshold = 0.9
high_corr = corr_matrix.abs() > threshold
to_drop = set()

#find cols which have corr greater than threshold
for i in range(len(high_corr.columns)):
    for j in range(i):
        if high_corr.iloc[i, j]:
            colName_i = high_corr.columns[i]
            colName_j = high_corr.columns[j]
            if colName_i not in to_drop and colName_j not in to_drop:
                to_drop.add(colName_j)

#drop cols and store X in new df
X_reduced = X.drop(columns=to_drop)

# %%
print("\nData Description Before Normalization:")
print(X_reduced.describe())
# Out:
# Data Description Before Normalization:
#            Dst Port      Protocol  Fwd Pkt Len Std  Bwd Pkt Len Min  \
# count  1.252846e+06  1.252846e+06     1.252846e+06     1.252846e+06
# mean   9.588155e+03  8.313469e+00     7.700061e+01     2.197513e+01
# std    1.935468e+04  4.619283e+00     1.200345e+02     4.806628e+01
# min    0.000000e+00  0.000000e+00     0.000000e+00     0.000000e+00
# 25%    5.300000e+01  6.000000e+00     0.000000e+00     0.000000e+00
# 50%    8.000000e+01  6.000000e+00     0.000000e+00     0.000000e+00
# 75%    3.389000e+03  6.000000e+00     1.397511e+02     0.000000e+00
# max    6.553400e+04  1.700000e+01     5.579582e+03     1.050000e+03
#
#         Flow Byts/s   Fwd IAT Tot  Fwd IAT Mean   Fwd IAT Max   Fwd IAT Min  \
# count  1.252846e+06  1.252846e+06  1.252846e+06  1.252846e+06  1.252846e+06
# mean   2.629520e+05  1.174706e+07  4.155316e+06  6.583450e+06  4.322050e+06
# std    3.797400e+06  3.063698e+07  7.404482e+08  1.954620e+07  1.742660e+07
# min    0.000000e+00  0.000000e+00 -8.282200e+11 -1.610514e+09  0.000000e+00
# 25%    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 50%    7.885739e+02  3.298000e+03  2.245000e+03  3.208000e+03  7.700000e+01
# 75%    7.285229e+04  1.465696e+06  2.377992e+05  9.531255e+05  1.368000e+03
# max    1.298500e+09  7.086881e+08  1.200000e+08  7.086881e+08  1.262566e+09
#
#         Bwd IAT Tot  ...  Subflow Bwd Byts  Init Fwd Win Byts  \
# count  1.252846e+06  ...      1.252846e+06       1.252846e+06
# mean   6.492204e+06  ...      5.579392e+03       1.493192e+04
# std    2.396192e+07  ...      2.826714e+05       2.132031e+04
# min    0.000000e+00  ...      0.000000e+00      -1.000000e+00
# 25%    0.000000e+00  ...      0.000000e+00       1.270000e+02
# 50%    0.000000e+00  ...      1.000000e+02       8.192000e+03
# 75%    9.952775e+04  ...      4.880000e+02       2.688300e+04
# max    1.200000e+08  ...      1.009997e+08       6.553500e+04
#
#        Init Bwd Win Byts  Fwd Act Data Pkts  Fwd Seg Size Min    Active Std  \
# count       1.252846e+06       1.252846e+06      1.252846e+06  1.252846e+06
# mean        9.178897e+03       1.237123e+00      1.830886e+01  3.308383e+04
# std         2.041888e+04       2.605071e+02      7.243993e+00  5.714664e+05
# min        -1.000000e+00      -3.266400e+04      0.000000e+00  0.000000e+00
# 25%        -1.000000e+00       0.000000e+00      2.000000e+01  0.000000e+00
# 50%         0.000000e+00       0.000000e+00      2.000000e+01  0.000000e+00
# 75%         2.550000e+02       1.000000e+00      2.000000e+01  0.000000e+00
# max         6.553500e+04       3.217200e+04      4.800000e+01  5.739751e+07
#
#          Active Max    Active Min      Idle Max      Idle Min
# count  1.252846e+06  1.252846e+06  1.252846e+06  1.252846e+06
# mean   1.186159e+05  5.104884e+04  5.441625e+06  4.966927e+06
# std    1.398053e+06  9.293325e+05  2.907424e+08  2.632555e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.110000e+08  1.110000e+08  3.248070e+11  2.175600e+10
#
# [8 rows x 49 columns]

# %%
eda_df = X_reduced.copy()
eda_df['target'] = Y_bin.reset_index(drop=True)

correlations = eda_df.corr(numeric_only=True)['target'].abs().sort_values(ascending=False)
top_features = correlations.drop('target').head(16).index.tolist()

subset_df = eda_df[top_features + ['target']]

associations(
    subset_df,
    nominal_columns='auto',
    figsize=(18, 18),
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    title="Associations Among Top 16 Features After Correlation Reduction",
    cbar=False
)
# Out:
# {'corr':                    Fwd Seg Size Min  Init Fwd Win Byts  Bwd Pkts/s  Protocol  \
#  Fwd Seg Size Min           1.000000           0.322275    0.484619 -0.695262
#  Init Fwd Win Byts          0.322275           1.000000    0.061032 -0.350785
#  Bwd Pkts/s                 0.484619           0.061032    1.000000 -0.089422
#  Protocol                  -0.695262          -0.350785   -0.089422  1.000000
#  ACK Flag Cnt               0.228171           0.038825   -0.058614 -0.354147
#  Bwd Pkt Len Min           -0.644815          -0.319192   -0.081961  0.851533
#  Init Bwd Win Byts          0.107274           0.150700   -0.081186 -0.225162
#  Pkt Len Min               -0.592291          -0.293143   -0.074379  0.782197
#  Dst Port                   0.114142           0.375721   -0.065790 -0.242222
#  Bwd Seg Size Avg          -0.036310           0.011292   -0.119714 -0.011447
#  Fwd IAT Tot               -0.005518           0.076330   -0.072209 -0.219078
#  Fwd Seg Size Avg          -0.000054           0.298405   -0.146176 -0.061303
#  Pkt Len Std                0.143963           0.254449   -0.136308 -0.260639
#  Fwd IAT Max                0.011954           0.208918   -0.063431 -0.189328
#  Pkt Len Var                0.128349           0.171448   -0.091097 -0.233564
#  Fwd Pkts/s                 0.300948          -0.012215    0.546341 -0.093325
#  target                     0.481460           0.303419    0.302897 -0.268338
#
#                     ACK Flag Cnt  Bwd Pkt Len Min  Init Bwd Win Byts  \
#  Fwd Seg Size Min       0.228171        -0.644815           0.107274
#  Init Fwd Win Byts      0.038825        -0.319192           0.150700
#  Bwd Pkts/s            -0.058614        -0.081961          -0.081186
#  Protocol              -0.354147         0.851533          -0.225162
#  ACK Flag Cnt           1.000000        -0.315985          -0.291983
#  Bwd Pkt Len Min       -0.315985         1.000000          -0.204226
#  Init Bwd Win Byts     -0.291983        -0.204226           1.000000
#  Pkt Len Min           -0.291161         0.713484          -0.188378
#  Dst Port               0.253471        -0.224930           0.128027
#  Bwd Seg Size Avg      -0.444783         0.055541           0.232273
#  Fwd IAT Tot            0.042998        -0.164556          -0.108759
#  Fwd Seg Size Avg      -0.527852        -0.053553           0.553307
#  Pkt Len Std           -0.496279        -0.203616           0.475770
#  Fwd IAT Max            0.198270        -0.143943          -0.118908
#  Pkt Len Var           -0.330300        -0.205009           0.287602
#  Fwd Pkts/s             0.072800        -0.085426          -0.083678
#  target                 0.249186        -0.246304          -0.239694
#
#                     Pkt Len Min  Dst Port  Bwd Seg Size Avg  Fwd IAT Tot  \
#  Fwd Seg Size Min     -0.592291  0.114142         -0.036310    -0.005518
#  Init Fwd Win Byts    -0.293143  0.375721          0.011292     0.076330
#  Bwd Pkts/s           -0.074379 -0.065790         -0.119714    -0.072209
#  Protocol              0.782197 -0.242222         -0.011447    -0.219078
#  ACK Flag Cnt         -0.291161  0.253471         -0.444783     0.042998
#  Bwd Pkt Len Min       0.713484 -0.224930          0.055541    -0.164556
#  Init Bwd Win Byts    -0.188378  0.128027          0.232273    -0.108759
#  Pkt Len Min           1.000000 -0.198041         -0.009503    -0.114877
#  Dst Port             -0.198041  1.000000         -0.136501    -0.042579
#  Bwd Seg Size Avg     -0.009503 -0.136501          1.000000     0.226283
#  Fwd IAT Tot          -0.114877 -0.042579          0.226283     1.000000
#  Fwd Seg Size Avg      0.073182  0.184207          0.402227    -0.050813
#  Pkt Len Std          -0.224178  0.039680          0.849169     0.211730
#  Fwd IAT Max          -0.100155  0.055437          0.065665     0.778908
#  Pkt Len Var          -0.196213  0.017669          0.877804     0.265898
#  Fwd Pkts/s           -0.077599  0.129517         -0.123338    -0.073658
#  target               -0.223835 -0.216085         -0.207115    -0.188536
#
#                     Fwd Seg Size Avg  Pkt Len Std  Fwd IAT Max  Pkt Len Var  \
#  Fwd Seg Size Min          -0.000054     0.143963     0.011954     0.128349
#  Init Fwd Win Byts          0.298405     0.254449     0.208918     0.171448
#  Bwd Pkts/s                -0.146176    -0.136308    -0.063431    -0.091097
#  Protocol                  -0.061303    -0.260639    -0.189328    -0.233564
#  ACK Flag Cnt              -0.527852    -0.496279     0.198270    -0.330300
#  Bwd Pkt Len Min           -0.053553    -0.203616    -0.143943    -0.205009
#  Init Bwd Win Byts          0.553307     0.475770    -0.118908     0.287602
#  Pkt Len Min                0.073182    -0.224178    -0.100155    -0.196213
#  Dst Port                   0.184207     0.039680     0.055437     0.017669
#  Bwd Seg Size Avg           0.402227     0.849169     0.065665     0.877804
#  Fwd IAT Tot               -0.050813     0.211730     0.778908     0.265898
#  Fwd Seg Size Avg           1.000000     0.694600    -0.111846     0.520713
#  Pkt Len Std                0.694600     1.000000     0.023141     0.897082
#  Fwd IAT Max               -0.111846     0.023141     1.000000     0.096573
#  Pkt Len Var                0.520713     0.897082     0.096573     1.000000
#  Fwd Pkts/s                -0.143638    -0.136240    -0.064708    -0.092597
#  target                    -0.177857    -0.163406    -0.163279    -0.138303
#
#                     Fwd Pkts/s    target
#  Fwd Seg Size Min     0.300948  0.481460
#  Init Fwd Win Byts   -0.012215  0.303419
#  Bwd Pkts/s           0.546341  0.302897
#  Protocol            -0.093325 -0.268338
#  ACK Flag Cnt         0.072800  0.249186
#  Bwd Pkt Len Min     -0.085426 -0.246304
#  Init Bwd Win Byts   -0.083678 -0.239694
#  Pkt Len Min         -0.077599 -0.223835
#  Dst Port             0.129517 -0.216085
#  Bwd Seg Size Avg    -0.123338 -0.207115
#  Fwd IAT Tot         -0.073658 -0.188536
#  Fwd Seg Size Avg    -0.143638 -0.177857
#  Pkt Len Std         -0.136240 -0.163406
#  Fwd IAT Max         -0.064708 -0.163279
#  Pkt Len Var         -0.092597 -0.138303
#  Fwd Pkts/s           1.000000  0.133166
#  target               0.133166  1.000000  ,
#  'ax': <Axes: title={'center': 'Associations Among Top 16 Features After Correlation Reduction'}>}

# %%
#normalize the data using MinMaxScaler
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(X_reduced)
X_normalized = pd.DataFrame(normalized_data, columns=X_reduced.columns)

# %%
eda_df = X_normalized.copy()
eda_df['target'] = Y_bin.reset_index(drop=True)

correlations = eda_df.corr(numeric_only=True)['target'].abs().sort_values(ascending=False)
top_features = correlations.drop('target').head(16).index.tolist()

subset_df = eda_df[top_features + ['target']]

# Associations plot with updated title
associations(
    subset_df,
    nominal_columns='auto',
    figsize=(18, 18),
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    title="Associations Among Top 16 Features After Correlation Reduction and Normalization",
    cbar=False
)
# Out:
# {'corr':                    Fwd Seg Size Min  Init Fwd Win Byts  Bwd Pkts/s  Protocol  \
#  Fwd Seg Size Min           1.000000           0.322275    0.484619 -0.695262
#  Init Fwd Win Byts          0.322275           1.000000    0.061032 -0.350785
#  Bwd Pkts/s                 0.484619           0.061032    1.000000 -0.089422
#  Protocol                  -0.695262          -0.350785   -0.089422  1.000000
#  ACK Flag Cnt               0.228171           0.038825   -0.058614 -0.354147
#  Bwd Pkt Len Min           -0.644815          -0.319192   -0.081961  0.851533
#  Init Bwd Win Byts          0.107274           0.150700   -0.081186 -0.225162
#  Pkt Len Min               -0.592291          -0.293143   -0.074379  0.782197
#  Dst Port                   0.114142           0.375721   -0.065790 -0.242222
#  Bwd Seg Size Avg          -0.036310           0.011292   -0.119714 -0.011447
#  Fwd IAT Tot               -0.005518           0.076330   -0.072209 -0.219078
#  Fwd Seg Size Avg          -0.000054           0.298405   -0.146176 -0.061303
#  Pkt Len Std                0.143963           0.254449   -0.136308 -0.260639
#  Fwd IAT Max                0.011954           0.208918   -0.063431 -0.189328
#  Pkt Len Var                0.128349           0.171448   -0.091097 -0.233564
#  Fwd Pkts/s                 0.300948          -0.012215    0.546341 -0.093325
#  target                     0.481460           0.303419    0.302897 -0.268338
#
#                     ACK Flag Cnt  Bwd Pkt Len Min  Init Bwd Win Byts  \
#  Fwd Seg Size Min       0.228171        -0.644815           0.107274
#  Init Fwd Win Byts      0.038825        -0.319192           0.150700
#  Bwd Pkts/s            -0.058614        -0.081961          -0.081186
#  Protocol              -0.354147         0.851533          -0.225162
#  ACK Flag Cnt           1.000000        -0.315985          -0.291983
#  Bwd Pkt Len Min       -0.315985         1.000000          -0.204226
#  Init Bwd Win Byts     -0.291983        -0.204226           1.000000
#  Pkt Len Min           -0.291161         0.713484          -0.188378
#  Dst Port               0.253471        -0.224930           0.128027
#  Bwd Seg Size Avg      -0.444783         0.055541           0.232273
#  Fwd IAT Tot            0.042998        -0.164556          -0.108759
#  Fwd Seg Size Avg      -0.527852        -0.053553           0.553307
#  Pkt Len Std           -0.496279        -0.203616           0.475770
#  Fwd IAT Max            0.198270        -0.143943          -0.118908
#  Pkt Len Var           -0.330300        -0.205009           0.287602
#  Fwd Pkts/s             0.072800        -0.085426          -0.083678
#  target                 0.249186        -0.246304          -0.239694
#
#                     Pkt Len Min  Dst Port  Bwd Seg Size Avg  Fwd IAT Tot  \
#  Fwd Seg Size Min     -0.592291  0.114142         -0.036310    -0.005518
#  Init Fwd Win Byts    -0.293143  0.375721          0.011292     0.076330
#  Bwd Pkts/s           -0.074379 -0.065790         -0.119714    -0.072209
#  Protocol              0.782197 -0.242222         -0.011447    -0.219078
#  ACK Flag Cnt         -0.291161  0.253471         -0.444783     0.042998
#  Bwd Pkt Len Min       0.713484 -0.224930          0.055541    -0.164556
#  Init Bwd Win Byts    -0.188378  0.128027          0.232273    -0.108759
#  Pkt Len Min           1.000000 -0.198041         -0.009503    -0.114877
#  Dst Port             -0.198041  1.000000         -0.136501    -0.042579
#  Bwd Seg Size Avg     -0.009503 -0.136501          1.000000     0.226283
#  Fwd IAT Tot          -0.114877 -0.042579          0.226283     1.000000
#  Fwd Seg Size Avg      0.073182  0.184207          0.402227    -0.050813
#  Pkt Len Std          -0.224178  0.039680          0.849169     0.211730
#  Fwd IAT Max          -0.100155  0.055437          0.065665     0.778908
#  Pkt Len Var          -0.196213  0.017669          0.877804     0.265898
#  Fwd Pkts/s           -0.077599  0.129517         -0.123338    -0.073658
#  target               -0.223835 -0.216085         -0.207115    -0.188536
#
#                     Fwd Seg Size Avg  Pkt Len Std  Fwd IAT Max  Pkt Len Var  \
#  Fwd Seg Size Min          -0.000054     0.143963     0.011954     0.128349
#  Init Fwd Win Byts          0.298405     0.254449     0.208918     0.171448
#  Bwd Pkts/s                -0.146176    -0.136308    -0.063431    -0.091097
#  Protocol                  -0.061303    -0.260639    -0.189328    -0.233564
#  ACK Flag Cnt              -0.527852    -0.496279     0.198270    -0.330300
#  Bwd Pkt Len Min           -0.053553    -0.203616    -0.143943    -0.205009
#  Init Bwd Win Byts          0.553307     0.475770    -0.118908     0.287602
#  Pkt Len Min                0.073182    -0.224178    -0.100155    -0.196213
#  Dst Port                   0.184207     0.039680     0.055437     0.017669
#  Bwd Seg Size Avg           0.402227     0.849169     0.065665     0.877804
#  Fwd IAT Tot               -0.050813     0.211730     0.778908     0.265898
#  Fwd Seg Size Avg           1.000000     0.694600    -0.111846     0.520713
#  Pkt Len Std                0.694600     1.000000     0.023141     0.897082
#  Fwd IAT Max               -0.111846     0.023141     1.000000     0.096573
#  Pkt Len Var                0.520713     0.897082     0.096573     1.000000
#  Fwd Pkts/s                -0.143638    -0.136240    -0.064708    -0.092597
#  target                    -0.177857    -0.163406    -0.163279    -0.138303
#
#                     Fwd Pkts/s    target
#  Fwd Seg Size Min     0.300948  0.481460
#  Init Fwd Win Byts   -0.012215  0.303419
#  Bwd Pkts/s           0.546341  0.302897
#  Protocol            -0.093325 -0.268338
#  ACK Flag Cnt         0.072800  0.249186
#  Bwd Pkt Len Min     -0.085426 -0.246304
#  Init Bwd Win Byts   -0.083678 -0.239694
#  Pkt Len Min         -0.077599 -0.223835
#  Dst Port             0.129517 -0.216085
#  Bwd Seg Size Avg    -0.123338 -0.207115
#  Fwd IAT Tot         -0.073658 -0.188536
#  Fwd Seg Size Avg    -0.143638 -0.177857
#  Pkt Len Std         -0.136240 -0.163406
#  Fwd IAT Max         -0.064708 -0.163279
#  Pkt Len Var         -0.092597 -0.138303
#  Fwd Pkts/s           1.000000  0.133166
#  target               0.133166  1.000000  ,
#  'ax': <Axes: title={'center': 'Associations Among Top 16 Features After Correlation Reduction and Normalization'}>}

# %%
sns.set_style('whitegrid')

features_per_plot = 4  # 4 plots per figure

for plot_idx in range(4):  # 4 figures
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle(f'Strip Plots of Selected Features by Traffic Type After Normalization (Part {plot_idx + 1})', fontsize=20)

    for i in range(features_per_plot):
        feature_idx = plot_idx * features_per_plot + i
        if feature_idx >= len(top_features):
            break

        feature = top_features[feature_idx]
        row, col = divmod(i, 2)

        sns.stripplot(
            data=eda_df, x='target', y=feature, hue='target', dodge=False,
            jitter=0.3, alpha=0.6, ax=axes[row, col], palette={0: 'green', 1: 'red'}
        )
        axes[row, col].set_title(f'{feature} vs Target')
        axes[row, col].legend_.remove()
        axes[row, col].set_xlabel("Traffic Type (0 = Normal, 1 = Attack)")

    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, ['Normal', 'Attack'], loc='upper right', fontsize=14)

    plt.tight_layout()
    plt.subplots_adjust(top=0.90)
    plt.show()

# %%
print("\nData Description After Normalization:")
print(X_normalized.describe())
# Out:
# Data Description After Normalization:
#            Dst Port      Protocol  Fwd Pkt Len Std  Bwd Pkt Len Min  \
# count  1.252846e+06  1.252846e+06     1.252846e+06     1.252846e+06
# mean   1.463081e-01  4.890276e-01     1.380043e-02     2.092869e-02
# std    2.953380e-01  2.717225e-01     2.151317e-02     4.577741e-02
# min    0.000000e+00  0.000000e+00     0.000000e+00     0.000000e+00
# 25%    8.087405e-04  3.529412e-01     0.000000e+00     0.000000e+00
# 50%    1.220740e-03  3.529412e-01     0.000000e+00     0.000000e+00
# 75%    5.171361e-02  3.529412e-01     2.504687e-02     0.000000e+00
# max    1.000000e+00  1.000000e+00     1.000000e+00     1.000000e+00
#
#         Flow Byts/s   Fwd IAT Tot  Fwd IAT Mean   Fwd IAT Max   Fwd IAT Min  \
# count  1.252846e+06  1.252846e+06  1.252846e+06  1.252846e+06  1.252846e+06
# mean   2.025044e-04  1.657578e-02  9.998601e-01  6.972646e-01  3.423227e-03
# std    2.924451e-03  4.323055e-02  8.938941e-04  8.427981e-03  1.380253e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  1.411058e-09  9.998551e-01  6.944260e-01  0.000000e+00
# 50%    6.072960e-07  4.653669e-06  9.998551e-01  6.944273e-01  6.098691e-08
# 75%    5.610496e-05  2.068181e-03  9.998554e-01  6.948369e-01  1.083508e-06
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#         Bwd IAT Tot  ...  Subflow Bwd Byts  Init Fwd Win Byts  \
# count  1.252846e+06  ...      1.252846e+06       1.252846e+06
# mean   5.410170e-02  ...      5.524168e-05       2.278583e-01
# std    1.996827e-01  ...      2.798736e-03       3.253222e-01
# min    0.000000e+00  ...      0.000000e+00       0.000000e+00
# 25%    0.000000e+00  ...      0.000000e+00       1.953125e-03
# 50%    0.000000e+00  ...      9.901022e-07       1.250153e-01
# 75%    8.293979e-04  ...      4.831699e-06       4.102173e-01
# max    1.000000e+00  ...      1.000000e+00       1.000000e+00
#
#        Init Bwd Win Byts  Fwd Act Data Pkts  Fwd Seg Size Min    Active Std  \
# count       1.252846e+06       1.252846e+06      1.252846e+06  1.252846e+06
# mean        1.400741e-01       5.038133e-01      3.814345e-01  5.763983e-04
# std         3.115674e-01       4.017939e-03      1.509165e-01  9.956292e-03
# min         0.000000e+00       0.000000e+00      0.000000e+00  0.000000e+00
# 25%         0.000000e+00       5.037942e-01      4.166667e-01  0.000000e+00
# 50%         1.525879e-05       5.037942e-01      4.166667e-01  0.000000e+00
# 75%         3.906250e-03       5.038096e-01      4.166667e-01  0.000000e+00
# max         1.000000e+00       1.000000e+00      1.000000e+00  1.000000e+00
#
#          Active Max    Active Min      Idle Max      Idle Min
# count  1.252846e+06  1.252846e+06  1.252846e+06  1.252846e+06
# mean   1.068612e-03  4.598995e-04  1.675341e-05  2.283015e-04
# std    1.259507e-02  8.372365e-03  8.951236e-04  1.210036e-03
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
# [8 rows x 49 columns]

# %%
print(f"Min value of X after Normalization: {X_normalized.min().min()}")
print(f"Max value of X after Normalization: {X_normalized.max().max()}")
# Out:
# Min value of X after Normalization: 0.0
# Max value of X after Normalization: 1.0

# %%
#free memory
del df1
del X
del X_reduced
del eda_df
del subset_df
del correlations
del top_features

# %%
#split dataframe into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_normalized, Y_bin, test_size=0.25, stratify=Y_bin, random_state=42)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (939634, 49)
# X_test shape: (313212, 49)
# y_train shape: (939634,)
# y_test shape: (313212,)

# %%
# Export to CSV
X_train.to_csv("X_train_bin.csv", index=False)
X_test.to_csv("X_test_bin.csv", index=False)
y_train.to_csv("y_train_bin.csv", index=False)
y_test.to_csv("y_test_bin.csv", index=False)

# %%
del Y_bin
del X_train
del X_test
del y_train
del y_test

# %%
#split dataframe into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_normalized, Y_multi, test_size=0.25, stratify=Y_multi, random_state=42)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (939634, 49)
# X_test shape: (313212, 49)
# y_train shape: (939634,)
# y_test shape: (313212,)

# %%
# Export to CSV
X_train.to_csv("X_train_multi.csv", index=False)
X_test.to_csv("X_test_multi.csv", index=False)
y_train.to_csv("y_train_multi.csv", index=False)
y_test.to_csv("y_test_multi.csv", index=False)

# %%
#free memory
del X_normalized
del X_train
del X_test
del y_train
del y_test
